# %% [markdown]
# # Индивидуальное задание
# <font size="4">Восстановить используя пороговый и адаптивный метод

# %% [markdown]
# 1. Загрузка библиотек

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
import random
from PIL import Image, ImageDraw

# %% [markdown]
# 2. Загрузка изображения

# %%
img = cv2.imread('img.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# 3. Пороговая обработка

# %%
# Применение порогового метода Otsu
ret, threshold = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
threshold = cv2.cvtColor(threshold, cv2.COLOR_BGR2RGB)
# Применение адаптивного метода
adaptive_threshold = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11, 2)
adaptive_threshold = cv2.cvtColor(adaptive_threshold, cv2.COLOR_BGR2RGB)

# %% [markdown]
# 4. Вывод изображения

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgs = [img, threshold, adaptive_threshold] 
titles = ['Original Noise',"Otsu’s", 'Adaptive']

for i in range(3):
    plt.subplot(2,3,i+1)
    plt.imshow(imgs[i])
    plt.xticks([]),plt.yticks([])
    plt.title(titles[i])
    
plt.show()
